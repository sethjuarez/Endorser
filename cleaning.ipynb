# %%
import numpy as np
import pandas as pd
import azureml.dataprep as dprep
# Out:
# c:\programdata\miniconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.24) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# # Load and Explore Movie Data
# Using the new Microsoft Data Preparation SDK (in public preview)

# %%
movies = dprep.read_csv(path='data/ml-latest-small/movies.csv', 
                        inference_arguments=dprep.InferenceArguments.current_culture())
movies.get_profile()
# Out:
# ColumnProfile
#     name: movieId
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 193609.0
#     count: 9742.0
#     missing_count: 0.0
#     error_count: 0.0
#
#     lower_quartile: 3239.686262173104
#     median: 7288.782060383902
#     upper_quartile: 76386.29476203126
#     std: 52160.49485443824
#     mean: 42200.35362348604
#
# ColumnProfile
#     name: title
#     type: FieldType.STRING
#
#     min: '71 (2014)
#     max: À nous la liberté (Freedom for Us) (1931)
#     count: 9742.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: genres
#     type: FieldType.STRING
#
#     min: (no genres listed)
#     max: Western
#     count: 9742.0
#     missing_count: 0.0
#     error_count: 0.0

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0      1.0                    Toy Story (1995)
# 1      2.0                      Jumanji (1995)
# 2      3.0             Grumpier Old Men (1995)
# 3      4.0            Waiting to Exhale (1995)
# 4      5.0  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Extract Genres
# This is the part where we extract all of the genres

# %%
df = movies.to_pandas_dataframe()
g = set()
for item in df['genres']:
    g = g | set([i.strip() for i in str(item).split('|')])
print(g)
# Out:
# {'Western', 'Fantasy', 'Animation', 'Drama', 'Musical', 'Horror', 'Crime', 'Documentary', 'Action', 'Film-Noir', 'Thriller', 'Comedy', 'IMAX', '(no genres listed)', 'Children', 'War', 'Mystery', 'Adventure', 'Romance', 'Sci-Fi'}

# %%
genres = ['Documentary', 'Children', 'Action', 'Film-Noir', 'Drama', 
          'Adventure', 'Fantasy', 'IMAX', 'Mystery', 'Musical', 'Sci-Fi', 
          'War', 'Crime', '(no genres listed)', 'Romance', 'Comedy', 'Thriller', 
          'Western', 'Animation', 'Horror']

# %% [markdown]
# # Add Column Per Genre
# This is to add a one-hot style encoding to genres

# %%
for item in genres:
    movies = movies.add_column(new_column_name=item, 
                               prior_column='genres', 
                               expression=dprep.col('genres').contains(item))
movies.head(5)
# Out:
#    movieId                               title  \
# 0      1.0                    Toy Story (1995)
# 1      2.0                      Jumanji (1995)
# 2      3.0             Grumpier Old Men (1995)
# 3      4.0            Waiting to Exhale (1995)
# 4      5.0  Father of the Bride Part II (1995)
#
#                                         genres  Horror  Animation  Western  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   False       True    False
# 1                   Adventure|Children|Fantasy   False      False    False
# 2                               Comedy|Romance   False      False    False
# 3                         Comedy|Drama|Romance   False      False    False
# 4                                       Comedy   False      False    False
#
#    Thriller  Comedy  Romance  (no genres listed)     ...       Musical  \
# 0     False    True    False               False     ...         False
# 1     False   False    False               False     ...         False
# 2     False    True     True               False     ...         False
# 3     False    True     True               False     ...         False
# 4     False    True    False               False     ...         False
#
#    Mystery   IMAX  Fantasy  Adventure  Drama  Film-Noir  Action  Children  \
# 0    False  False     True       True  False      False   False      True
# 1    False  False     True       True  False      False   False      True
# 2    False  False    False      False  False      False   False     False
# 3    False  False    False      False   True      False   False     False
# 4    False  False    False      False  False      False   False     False
#
#    Documentary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 23 columns]

# %% [markdown]
# # Save Data Preparation Steps
# Create and save dprep file

# %%
movies = movies.set_name(name='movies')
package = dprep.Package(arg=movies)
package = package.save(file_path='movies.dprep')
